# %% [markdown]
# <div style="text-align: center">
#   <img src="../Course Materials/Images/ciai_logo_smaller.png" width="400"/>
# </div>

# %% [markdown]
# # Welcome to A Catholic Introduction to Artificial Intelligence Class 1!
#
# “The question is not whether intelligent machines can have any emotions, but whether machines can be intelligent without any emotions.” – Marvin Minsky

# %% [markdown]
# ## Learning Objectives
#
# By the end of this class, students will be able to:
#
# 1.	Understand the course objectives, requirements, and expectations.
#
# 2.  Define Artificial Intelligence (AI) in their own words.
# 3.	Distinguish between AI, Machine Learning (ML), and Deep Learning (DL).
# 4.	Identify examples of AI in their daily lives.
# 5.	Begin to think critically about what AI is and what it is not.

# %% [markdown]
# ## 1A. Course Objectives

# %% [markdown]
# The Catholic Church views science to explore and comprehend the natural world created by God. Technology is encouraged when it respects ethical principles and upholds the dignity of human life. Catholics recognize the benefits of technological advancements for improving human life and society. Moral discernment is crucial to guide technology to serve humanity ethically and avoid harm or injustice.
#
# This course integrates faith and technology to explore faith, ethics, and AI advancements together. This course will not teach students how to exploit AI concepts that violate academic integrity. Its main goal is to introduce the student AI concepts and the technology that makes it happen. Over the course of the topics, students will understand the so-called truth that AI provides and the truth that it doesn’t provide. And it will cut through the fantasy and hype so often attributed to AI.
#
# To summarize:
#
# - Become critical thinkers and responsible users.
#
# - Understand how AI impacts privacy, ethics, employment, and truth.

# %% [markdown]
# # 1B. Course Prerequisites
#
# One of the following or equivalent:
#
# - Introduction to Computer Science, Part 1 or Part 2
#
# - Introduction to Computer Science Using SNAP!
# - Computer Programming 101 with Python
# - C# Programming with Unity 101

# %% [markdown]
# # 1C. Course Requirements
#
# This course uses the following AI-based tools:
#
# - `NotebookLM` is an AI research and study tool developed by Google that helps users understand and work with their own documents. Instead of answering questions from the general internet, it analyzes sources you upload—such as PDFs, Google Docs, or notes—and generates summaries, explanations, study guides, and even audio-style discussions based only on those materials. This makes it especially useful for research, learning, and organizing information because the AI stays grounded in the sources you provide. A Google account is required.
#
# - `Jupyter Notebook` is an open-source interactive computing environment where users can write code, display results, add explanations, and create visualizations all in one document. It is widely used in data science, machine learning, and AI because it allows programmers to run code step-by-step while documenting their work. This makes it especially useful for learning, experimentation, and sharing reproducible research. Jupyter Notebooks can be created and execute within a browser with no need to install any additional software. No account registration required.
# - `ChatGPT` (https://chatgpt.com/): an AI assistant that explains ideas, answers questions, researches information, and helps with writing, learning, planning, and problem-solving across many topics (from Chat GPT). No account registration required.
# - `Google Gemini` (https://gemini.google.com/app): I am Gemini 3 Flash, an adaptive AI collaborator. I’m here to help you create text, images, music, and video with clarity and wit (from Gemini). A Google account is required.
# - `Claude` (https://claude.ai/login): an AI assistant made by Anthropic. I can answer questions, write, analyze, code, and help with a wide range of tasks (from Claude). Account registration is required.
# - `Google Teachable Machine` is a web tool from Google that lets users train simple machine-learning models—like image, sound, or pose recognition—without coding. A Google account is required.
# - (Optional) Visual Studio Code (VSC): VSC is an integrated development environment (IDE) that aids in the writing, debugging, and execution of a large range of computer programs.  It also can handle Jupyter Notebooks.  Students with computer programming experience and who are familiar with VSC while find using VCS for Jupyter Notebooks quite easy. VSC software is free but it must be installed on the student’s computer or laptop.
# - (Optional) Google Colab: (short for Google Colaboratory) is a free cloud-based environment from Google that lets users write and run Python code in a web browser. It works like an online notebook where you can mix code, text explanations, and visualizations—making it popular for data science, machine learning, and AI experiments. Because it runs in the cloud and can provide access to GPUs, students can build and test AI models without installing software on their own computers (from ChatGPT). A Google account is required.

# %% [markdown]
# # 1D. Course Expectations
#
# This is a `live` course - you are expected to attend the live session each week.  The recording is not intended to be viewed for the first time; it is intended as a refresher after you have attended the weekly live class.
#
# Participation - use microphones.  Chat for questions or raise your hand.
#
# Essays
#
# This course will use the following Academic Integrity Policy (AIP) as it relates to the use of artificial intelligence.  All other common-sense integity policies also remain in effect.

# %% [markdown]
# <div style="text-align: center">
#   <img src="../Course Materials/Images/AI Assessment Scale.png" width="600"/>
# </div>

# %% [markdown]
# # 1E. Assessment Overview
#
# - Participation and discussions - 20%
#
# - Short essays - 30%
# - Quizzes- 10%
# - Final Project - 40%

# %% [markdown]
# ## 2. Define Artificial Intelligence (AI) in your own words.

# %% [markdown]
# What is AI to you? Define AI in your own words.

# %% [markdown]
# ### 2A. What is Artificial Intelligence (AI)?
#
# * Definition: AI is the field of computer science that focuses on creating systems capable of performing tasks that typically require human intelligence. This includes problem-solving, understanding language, recognizing patterns, and making decisions.
#
# * Examples: Siri, Google Translate, facial recognition, Netflix recommendations, email spam filters
# * Misconception: AI is not conscious, sentient, or creative. Most current AI is "narrow" or task-specific.

# %% [markdown]
# ### 2B: AI Capabilities
#
# * `Narrow` AI that is good at one specific task (or a narrow set of tasks)
#
#     * Examples are: spam filters, fraud detection models, recommendation systems, voice assistants, image classifiers, generative AI (ChatGPT, Copilot, Claude, etc.)
#     * Each of these systems can only perform well in its own domain
#     * Most AI systems today are `narrow` or `weak` AI
# * `General` AI can learn and performan any intellectual taks a human can
#     * Not a pre-programmed task
#     * Examples are: learn a new job without training, reason across domains, transfer knowledge
# * `Superintelligence` AI that is more capable that humans at essentially all intellectual tasks
#     * Can reason, create, discover, strategize, and socially understand all on its own
#     * Far beyond humans

# %% [markdown]
# ## 3. Distinguish between Computer Science, AI, Machine Learning (ML), and Deep Learning (DL).

# %% [markdown]
# AI is the broad concept of machines doing intelligent things.
#
# - Machine Learning (ML) is a subset of AI that uses data and algorithms to "learn" from experience using `labels`.
#
# - Deep Learning (DL) is a further subset of ML that uses artificial neural networks to model complex patterns.
# - Analogy: Think of AI as the universe, ML as a galaxy, and DL as a solar system within that galaxy.
# - Supervised Learning is a type of machine learning where a model is trained using **labeled data** — that is, data where the correct answers are already known. In this approach, the model learns by comparing its predictions to the correct answers and gradually improving over time. For example, if you train a model with many emails labeled “spam” or “not spam,” it learns patterns that help it classify new emails correctly. *You show the computer examples with the right answers, and it learns to predict those answers on its own.*
#
# - Unsupervised Learning is a type of machine learning where a model is given **unlabeled data** and must find patterns, groupings, or structure on its own. Unlike supervised learning, no one tells the model the “right answer” ahead of time. Instead, it looks for similarities or hidden relationships in the data. For example, a model might group customers into different categories based on buying behavior without being told what those categories should be. *The computer is given a pile of data and asked to discover what patterns are there by itself.*

# %% [markdown]
# Below is another way of describing this.

# %% [markdown]
# <div style="text-align: center">
#   <img src="../Course Materials/Images/CS Ven.png" width="600"/>
# </div>

# %% [markdown]
# This diagram shows how several important technology fields are related to one another. The biggest circle is **Computer Science**, which is the broad field that includes programming, software, hardware, networks, databases, cybersecurity, and much more. Inside computer science is **Artificial Intelligence**, which focuses specifically on building systems that can do things that seem intelligent, such as recognizing speech, making decisions, or understanding language.
#
# Inside artificial intelligence is **Machine Learning**, which is a more specific area where computers learn patterns from data instead of being told every rule directly by a programmer. For example, instead of programming every rule for identifying spam email, a machine learning system studies many examples of spam and non-spam messages and learns the patterns for itself.
#
# Inside machine learning is **Deep Learning**, which is an even more specialized approach that uses layers of artificial “neurons” called neural networks. Deep learning is what powers many of today’s most advanced AI systems, such as image recognition, voice assistants, and large language models like ChatGPT.
#
# The **Data Science** circle overlaps with AI and machine learning because these fields often use the same tools and data. However, data science is not exactly the same as AI. Data science is more focused on collecting, organizing, analyzing, and drawing conclusions from data. A data scientist might use machine learning, but they might also just use statistics, charts, and spreadsheets to answer questions.
#
# The main idea students should understand is this: **AI is part of computer science, machine learning is part of AI, and deep learning is part of machine learning.** Data science overlaps with all of them because data is essential to how modern AI works.

# %% [markdown]
# ## 4. Identify examples of AI in their daily lives.

# %% [markdown]
# Examples of AI in Everyday Life:
#
# - Smartphones: Voice assistants, auto-correct.
#
# - Streaming Services: Recommendation engines.
# - Social Media: Feed algorithms, facial tagging.
# - Navigation: Google Maps predicting traffic.
# - Retail: Chatbots, personalized ads.

# %% [markdown]
# ## 5. Ethics and Bias Teasers

# %% [markdown]
# - AI can make mistakes (e.g., false arrests due to facial recognition errors).
#
# - Data used to train AI can be biased.
# - Discussion: Should we always trust AI?
# - Discussion: Who is responsible when AI is wrong?

# %% [markdown]
# ## 6. Exit Ticket / Assessment:
#
# "What is one way you’ve used AI without realizing it? What do you hope to learn in this course?"

# %% [markdown]
# ## 7. Vocabulary
#
# - **Academic Integrity**
# The honest and responsible use of knowledge, work, and tools, including proper and ethical use of AI.
#
# - **Artificial Intelligence (AI)**
# The field of computer science that focuses on creating systems capable of performing tasks that typically require human intelligence, such as problem-solving, understanding language, recognizing patterns, and making decisions.
#
# - **Bias**
# A systematic unfairness in AI systems, often caused by biased data or flawed assumptions in how a model is built or trained.
#
# - **ChatGPT**
# An AI assistant that can explain ideas, answer questions, research information, and help with writing, learning, planning, and problem-solving.
#
# - **Claude**
# An AI assistant made by Anthropic that can answer questions, write, analyze, code, and help with a wide range of tasks.
#
# - **Computer Science**
# The broad field of study that includes programming, computing systems, software, and technologies such as artificial intelligence.
#
# - **Data**
# Information used by AI systems to learn patterns, make decisions, or generate outputs.
#
# - **Deep Learning (DL)**
# A subset of machine learning that uses artificial neural networks to model complex patterns.
#
# - **Ethics**
# The study of right and wrong in human actions, including how AI should be designed and used responsibly.
#
# - **Facial Recognition**
# An AI technology that identifies or verifies people by analyzing facial features.
#
# - **Fraud Detection Models**
# AI systems designed to detect suspicious behavior or transactions that may indicate fraud.
#
# - **General AI**
# A hypothetical type of AI that can learn and perform any intellectual task a human can do.
#
# - **Generative AI**
# AI systems that can create new content such as text, images, music, or other media.
#
# - **Google Colab**
# A free cloud-based environment from Google that lets users write and run Python code in a web browser.
#
# - **Google Gemini**
# An adaptive AI assistant from Google that can help create text, images, music, and video.
#
# - **Google Teachable Machine**
# A web tool from Google that lets users train simple machine-learning models—such as image, sound, or pose recognition—without coding.
#
# - **Image Classifiers**
# AI systems that identify or categorize images based on patterns learned from training data.
#
# - **Jupyter Notebook**
# An open-source interactive computing environment where users can write code, display results, add explanations, and create visualizations in one document.
#
# - **Labels**
# The correct answers or categories attached to data so a machine learning system can learn from examples.
#
# - **Machine Learning (ML)**
# A subset of AI that uses data and algorithms to learn from experience.
#
# - **Narrow AI**
# AI that is designed to perform one specific task or a narrow set of tasks.
#
# - **Neural Networks**
# A type of computing model used in deep learning that is inspired by the structure of the human brain.
#
# - **NotebookLM**
# An AI research and study tool developed by Google that helps users understand and work with their own uploaded documents.
#
# - **Privacy**
# The protection of personal information and the right to control how that information is collected and used.
#
# - **Recommendation Systems**
# AI systems that suggest products, videos, music, or other content based on user behavior and patterns.
#
# - **Spam Filters**
# AI or rule-based systems that detect and block unwanted or suspicious email messages.
#
# - **Superintelligence AI**
# A hypothetical AI that would be more capable than humans at essentially all intellectual tasks.
#
# - **Supervised Learning**
# A type of machine learning that learns from data using labels.
#
# - **Unsupervised Learning**
# A type of machine learning in which the system looks for patterns in data without being given labels.
#
# - **Voice Assistants**
# AI systems that respond to spoken language, such as Siri or Google Assistant.
